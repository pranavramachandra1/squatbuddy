# %%
from squat_buddy import SquatBuddy

from matplotlib import pyplot as plt   

import tensorflow as tf
import numpy as np
import cv2
from tqdm import tqdm

# %%
sb = SquatBuddy()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
body_data = sb.process_video("test_images/IMG_2422.MOV")

# %%
x_dat, y_dat, conf_dat = body_data.to_frame()

# %%
x_dat
# Out:
#           nose  left_eye  right_eye  left_ear  right_ear  left_shoulder  \
# 0     0.123958  0.114421   0.117620  0.109954   0.113329       0.132901
# 1     0.120575  0.112753   0.111539  0.108704   0.111318       0.130548
# 2     0.127728  0.121364   0.117453  0.119240   0.117893       0.149123
# 3     0.112318  0.108252   0.106331  0.111481   0.107818       0.143884
# 4     0.108229  0.098474   0.094362  0.107363   0.103502       0.139974
# ...        ...       ...        ...       ...        ...            ...
# 1223  0.160848  0.154999   0.155372  0.160150   0.146767       0.174561
# 1224  0.171411  0.166526   0.166690  0.169477   0.165086       0.179231
# 1225  0.209041  0.205148   0.206954  0.209325   0.199731       0.240393
# 1226  0.188170  0.183660   0.186462  0.180720   0.188081       0.172448
# 1227  0.196823  0.193453   0.195936  0.194149   0.200655       0.184165
#
#       right_shoulder  left_elbow  right_elbow  left_wrist  right_wrist  \
# ...

# %%
plt.plot(x_dat.iloc[conf_dat[conf_dat['left_hip'] > 0.55].index]['left_hip'])

# %%
plt.plot(conf_dat['left_hip'])

plt.plot(x_dat['left_hip'])
